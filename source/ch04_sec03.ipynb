# %%
import pandas as pd # pandas 모듈 호출
import numpy as np # numpy 모듈 호출

ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings', 'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
            'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
            'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
            'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}

df = pd.DataFrame(ipl_data)
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
df.groupby("Team")["Rank"].sum()
# Out:
# Team
# Devils    5
# Kings     5
# Riders    7
# Royals    5
# kings     4
# Name: Rank, dtype: int64

# %%
multi_groupby = df.groupby(["Team", "Rank"])["Points"].sum()
multi_groupby
# Out:
# Team    Rank
# Devils  2        863
#         3        673
# Kings   1       1544
#         3        741
# Riders  1        876
#         2       2173
# Royals  1        804
#         4        701
# kings   4        812
# Name: Points, dtype: int64

# %%
multi_groupby = df.groupby(["Team", "Year"])["Points"].sum()
multi_groupby.index
# Out:
# MultiIndex([('Devils', 2014),
#             ('Devils', 2015),
#             ( 'Kings', 2014),
#             ( 'Kings', 2016),
#             ( 'Kings', 2017),
#             ('Riders', 2014),
#             ('Riders', 2015),
#             ('Riders', 2016),
#             ('Riders', 2017),
#             ('Royals', 2014),
#             ('Royals', 2015),
#             ( 'kings', 2015)],
#            names=['Team', 'Year'])

# %%
multi_groupby["Devils":"Kings"]
# Out:
# Team    Year
# Devils  2014    863
#         2015    673
# Kings   2014    741
#         2016    756
#         2017    788
# Name: Points, dtype: int64

# %%
multi_groupby.unstack()
# Out:
# Year     2014   2015   2016   2017
# Team
# Devils  863.0  673.0    NaN    NaN
# Kings   741.0    NaN  756.0  788.0
# Riders  876.0  789.0  694.0  690.0
# Royals  701.0  804.0    NaN    NaN
# kings     NaN  812.0    NaN    NaN

# %%
multi_groupby.swaplevel().sort_index()
# Out:
# Year  Team
# 2014  Devils    863
#       Kings     741
#       Riders    876
#       Royals    701
# 2015  Devils    673
#       Riders    789
#       Royals    804
#       kings     812
# 2016  Kings     756
#       Riders    694
# 2017  Kings     788
#       Riders    690
# Name: Points, dtype: int64

# %%
multi_groupby.sum(level=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 multi_groupby.sum(level=0)
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\core\series.py:6528, in Series.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#    6519 @doc(make_doc("sum", ndim=1))
#    6520 def sum(
#    6521     self,
#    (...)
#    6526     **kwargs,
#    6527 ):
# -> 6528     return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\core\generic.py:12506, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12498 def sum(
#   12499     self,
#   12500     axis: Axis | None = 0,
#    (...)
#   12504     **kwargs,
#   12505 ):
# > 12506     return self._min_count_stat_function(
#   12507         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12508     )
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\core\generic.py:12471, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12459 @final
#   12460 def _min_count_stat_function(
#   12461     self,
#    (...)
#   12468     **kwargs,
#   12469 ):
#   12470     assert name in ["sum", "prod"], name
# > 12471     nv.validate_func(name, (), kwargs)
#   12473     validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   12475     if axis is None:
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\compat\numpy\function.py:418, in validate_func(fname, args, kwargs)
#     415     return validate_stat_func(args, kwargs, fname=fname)
#     417 validation_func = _validation_funcs[fname]
# --> 418 return validation_func(args, kwargs)
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\compat\numpy\function.py:88, in CompatValidator.__call__(self, args, kwargs, fname, max_fname_arg_count, method)
#      86     validate_kwargs(fname, kwargs, self.defaults)
#      87 elif method == "both":
# ---> 88     validate_args_and_kwargs(
#      89         fname, args, kwargs, max_fname_arg_count, self.defaults
#      90     )
#      91 else:
#      92     raise ValueError(f"invalid validation method '{method}'")
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\util\_validators.py:223, in validate_args_and_kwargs(fname, args, kwargs, max_fname_arg_count, compat_args)
#     218         raise TypeError(
#     219             f"{fname}() got multiple values for keyword argument '{key}'"
#     220         )
#     222 kwargs.update(args_dict)
# --> 223 validate_kwargs(fname, kwargs, compat_args)
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\util\_validators.py:164, in validate_kwargs(fname, kwargs, compat_args)
#     142 """
#     143 Checks whether parameters passed to the **kwargs argument in a
#     144 function `fname` are valid parameters as specified in `*compat_args`
#    (...)
#     161 map to the default values specified in `compat_args`
#     162 """
#     163 kwds = kwargs.copy()
# --> 164 _check_for_invalid_keys(fname, kwargs, compat_args)
#     165 _check_for_default_values(fname, kwds, compat_args)
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\util\_validators.py:138, in _check_for_invalid_keys(fname, kwargs, compat_args)
#     136 if diff:
#     137     bad_arg = next(iter(diff))
# --> 138     raise TypeError(f"{fname}() got an unexpected keyword argument '{bad_arg}'")
#
# TypeError: sum() got an unexpected keyword argument 'level'

# %%
multi_groupby.sum(level=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 multi_groupby.sum(level=1)
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\core\series.py:6528, in Series.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#    6519 @doc(make_doc("sum", ndim=1))
#    6520 def sum(
#    6521     self,
#    (...)
#    6526     **kwargs,
#    6527 ):
# -> 6528     return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\core\generic.py:12506, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12498 def sum(
#   12499     self,
#   12500     axis: Axis | None = 0,
#    (...)
#   12504     **kwargs,
#   12505 ):
# > 12506     return self._min_count_stat_function(
#   12507         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12508     )
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\core\generic.py:12471, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12459 @final
#   12460 def _min_count_stat_function(
#   12461     self,
#    (...)
#   12468     **kwargs,
#   12469 ):
#   12470     assert name in ["sum", "prod"], name
# > 12471     nv.validate_func(name, (), kwargs)
#   12473     validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   12475     if axis is None:
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\compat\numpy\function.py:418, in validate_func(fname, args, kwargs)
#     415     return validate_stat_func(args, kwargs, fname=fname)
#     417 validation_func = _validation_funcs[fname]
# --> 418 return validation_func(args, kwargs)
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\compat\numpy\function.py:88, in CompatValidator.__call__(self, args, kwargs, fname, max_fname_arg_count, method)
#      86     validate_kwargs(fname, kwargs, self.defaults)
#      87 elif method == "both":
# ---> 88     validate_args_and_kwargs(
#      89         fname, args, kwargs, max_fname_arg_count, self.defaults
#      90     )
#      91 else:
#      92     raise ValueError(f"invalid validation method '{method}'")
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\util\_validators.py:223, in validate_args_and_kwargs(fname, args, kwargs, max_fname_arg_count, compat_args)
#     218         raise TypeError(
#     219             f"{fname}() got multiple values for keyword argument '{key}'"
#     220         )
#     222 kwargs.update(args_dict)
# --> 223 validate_kwargs(fname, kwargs, compat_args)
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\util\_validators.py:164, in validate_kwargs(fname, kwargs, compat_args)
#     142 """
#     143 Checks whether parameters passed to the **kwargs argument in a
#     144 function `fname` are valid parameters as specified in `*compat_args`
#    (...)
#     161 map to the default values specified in `compat_args`
#     162 """
#     163 kwds = kwargs.copy()
# --> 164 _check_for_invalid_keys(fname, kwargs, compat_args)
#     165 _check_for_default_values(fname, kwds, compat_args)
#
# File c:\Users\goran\anaconda3\envs\junenv\Lib\site-packages\pandas\util\_validators.py:138, in _check_for_invalid_keys(fname, kwargs, compat_args)
#     136 if diff:
#     137     bad_arg = next(iter(diff))
# --> 138     raise TypeError(f"{fname}() got an unexpected keyword argument '{bad_arg}'")
#
# TypeError: sum() got an unexpected keyword argument 'level'

# %%
grouped = df.groupby("Team")
grouped.get_group("Riders")
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690

# %%
grouped.agg(min)
# Out:
# C:\Users\goran\AppData\Local\Temp\ipykernel_19372\1865845851.py:1: FutureWarning: The provided callable <built-in function min> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grouped.agg(min)
#         Rank  Year  Points
# Team
# Devils     2  2014     673
# Kings      1  2014     741
# Riders     1  2014     690
# Royals     1  2014     701
# kings      4  2015     812

# %%
grouped.agg(np.mean)
# Out:
# C:\Users\goran\AppData\Local\Temp\ipykernel_19372\1243003623.py:1: FutureWarning: The provided callable <function mean at 0x0000020A72AE2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped.agg(np.mean)
#             Rank         Year      Points
# Team
# Devils  2.500000  2014.500000  768.000000
# Kings   1.666667  2015.666667  761.666667
# Riders  1.750000  2015.500000  762.250000
# Royals  2.500000  2014.500000  752.500000
# kings   4.000000  2015.000000  812.000000

# %%
grouped.transform(max)
# Out:
# C:\Users\goran\AppData\Local\Temp\ipykernel_19372\416221584.py:1: FutureWarning: The provided callable <built-in function max> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped.transform(max)
#     Rank  Year  Points
# 0      2  2017     876
# 1      2  2017     876
# 2      3  2015     863
# 3      3  2015     863
# 4      3  2017     788
# 5      4  2015     812
# 6      3  2017     788
# 7      3  2017     788
# 8      2  2017     876
# 9      4  2015     804
# 10     4  2015     804
# 11     2  2017     876

# %%
score = lambda x: (x - x.mean()) / x.std()
grouped.transform(score)
# Out:
#         Rank      Year    Points
# 0  -1.500000 -1.161895  1.284327
# 1   0.500000 -0.387298  0.302029
# 2  -0.707107 -0.707107  0.707107
# 3   0.707107  0.707107 -0.707107
# 4   1.154701 -1.091089 -0.860862
# 5        NaN       NaN       NaN
# 6  -0.577350  0.218218 -0.236043
# 7  -0.577350  0.872872  1.096905
# 8   0.500000  0.387298 -0.770596
# 9   0.707107 -0.707107 -0.707107
# 10 -0.707107  0.707107  0.707107
# 11  0.500000  1.161895 -0.815759

# %%
df.groupby('Team').filter(
    lambda x: len(x) >= 3)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 4    Kings     3  2014     741
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690

# %%
df.groupby('Team').filter(
    lambda x:
    x["Points"].max() > 800)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 5    kings     4  2015     812
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690
